# %% [markdown]
# <a href="https://colab.research.google.com/github/yuroua20/fin_data/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "/content/損益表-累季.csv"

# %%
df = pd.read_csv(url, index_col=0)
df
# Out:
#                                    2731 雄獅  2739 寒舍 2731 雄獅.1 2739 寒舍.1  \
# 公司
# 年/月                                2023/12  2023/12   2023/09   2023/09
# 季別                                       4        4         3         3
# 合併(Y/N)                                  Y        Y         Y         Y
# 月份                                      12       12         9         9
# 幣別                                     NTD      NTD       NTD       NTD
# 營業收入                                 215.1    48.31     154.5     34.49
# 營業成本                                 182.7    29.66     131.3     21.86
# 營業毛利                                 32.41    18.65     23.22     12.63
# 營業毛利淨額                               32.41    18.65     23.22     12.63
# 推銷費用                                     -     2.83         -      1.99
# 管理費用                                     -    11.21         -      8.15
# 營業費用                                 23.08    14.04     16.94     10.14
# ...

# %%
df.head()
# Out:
#          2731 雄獅  2739 寒舍 2731 雄獅.1 2739 寒舍.1 2731 雄獅.2 2739 寒舍.2 2731 雄獅.3  \
# 公司
# 年/月      2023/12  2023/12   2023/09   2023/09   2023/06   2023/06   2023/03
# 季別             4        4         3         3         2         2         1
# 合併(Y/N)        Y        Y         Y         Y         Y         Y         Y
# 月份            12       12         9         9         6         6         3
# 幣別           NTD      NTD       NTD       NTD       NTD       NTD       NTD
#
#         2739 寒舍.3  (單位:億元)
# 公司
# 年/月       2023/03      NaN
# 季別              1      NaN
# 合併(Y/N)         Y      NaN
# 月份              3      NaN
# 幣別            NTD      NaN

# %%
df.columns
# Out:
# Index(['2731 雄獅', '2739 寒舍', '2731 雄獅.1', '2739 寒舍.1', '2731 雄獅.2',
#        '2739 寒舍.2', '2731 雄獅.3', '2739 寒舍.3', '(單位:億元)'],
#       dtype='object')

# %%
url = "/content/資產負債表-累季.csv"

# %%
df = pd.read_csv(url, index_col=0)
df
# Out:
#                         2731 雄獅  2739 寒舍 2731 雄獅.1 2739 寒舍.1 2731 雄獅.2  \
# 公司
# 年/月                     2023/12  2023/12   2023/09   2023/09   2023/06
# 季別                            4        4         3         3         2
# 合併(Y/N)                       Y        Y         Y         Y         Y
# 月份                           12       12         9         9         6
# 幣別                          NTD      NTD       NTD       NTD       NTD
# ...                         ...      ...       ...       ...       ...
# 股東權益總額                    38.22    11.86       NaN       NaN         -
# 待註銷股本股數(萬張)                   -        0       NaN       NaN     28.79
# 預收股款之約當發行股數(萬張)               0        0       NaN       NaN       NaN
# 母公司暨子公司持有之母公司庫藏股股數(萬張)        -        0       NaN       NaN       NaN
# 每股淨值(元)                      40    11.68       NaN       NaN       NaN
#
#                        2739 寒舍.2 2731 雄獅.3 2739 寒舍.3  (單位:億元)
# 公司
# ...

# %%
df.head()
# Out:
#          2731 雄獅  2739 寒舍 2731 雄獅.1 2739 寒舍.1 2731 雄獅.2 2739 寒舍.2 2731 雄獅.3  \
# 公司
# 年/月      2023/12  2023/12   2023/09   2023/09   2023/06   2023/06   2023/03
# 季別             4        4         3         3         2         2         1
# 合併(Y/N)        Y        Y         Y         Y         Y         Y         Y
# 月份            12       12         9         9         6         6         3
# 幣別           NTD      NTD       NTD       NTD       NTD       NTD       NTD
#
#         2739 寒舍.3  (單位:億元)
# 公司
# 年/月       2023/03      NaN
# 季別              1      NaN
# 合併(Y/N)         Y      NaN
# 月份              3      NaN
# 幣別            NTD      NaN

# %%
df.columns
# Out:
# Index(['2731 雄獅', '2739 寒舍', '2731 雄獅.1', '2739 寒舍.1', '2731 雄獅.2',
#        '2739 寒舍.2', '2731 雄獅.3', '2739 寒舍.3', '(單位:億元)'],
#       dtype='object')
